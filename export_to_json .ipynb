# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.decomposition import PCA

# import some data to play with
iris = datasets.load_iris()['data']

# %%
iris_df = pd.DataFrame(iris, columns=['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width'])

# %%
iris_df
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# 5             5.4          3.9           1.7          0.4
# 6             4.6          3.4           1.4          0.3
# 7             5.0          3.4           1.5          0.2
# 8             4.4          2.9           1.4          0.2
# 9             4.9          3.1           1.5          0.1
# 10            5.4          3.7           1.5          0.2
# 11            4.8          3.4           1.6          0.2
# 12            4.8          3.0           1.4          0.1
# 13            4.3          3.0           1.1          0.1
# 14            5.8          4.0           1.2          0.2
# ...

# %%
iris_json = iris_df.to_json(orient='records')

# %%
import json

# %%
new_iris = json.loads(iris_json)

# %%
type(new_iris)
# Out:
# list

# %%
new_iris
# Out:
# [{'Sepal_Length': 5.1,
#   'Sepal_Width': 3.5,
#   'Petal_Length': 1.4,
#   'Petal_Width': 0.2},
#  {'Sepal_Length': 4.9,
#   'Sepal_Width': 3.0,
#   'Petal_Length': 1.4,
#   'Petal_Width': 0.2},
#  {'Sepal_Length': 4.7,
#   'Sepal_Width': 3.2,
#   'Petal_Length': 1.3,
#   'Petal_Width': 0.2},
#  {'Sepal_Length': 4.6,
#   'Sepal_Width': 3.1,
#   'Petal_Length': 1.5,
#   'Petal_Width': 0.2},
#  {'Sepal_Length': 5.0,
#   'Sepal_Width': 3.6,
#   'Petal_Length': 1.4,
#   'Petal_Width': 0.2},
#  {'Sepal_Length': 5.4,
#   'Sepal_Width': 3.9,
#   'Petal_Length': 1.7,
#   'Petal_Width': 0.4},
#  {'Sepal_Length': 4.6,
#   'Sepal_Width': 3.4,
#   'Petal_Length': 1.4,
#   'Petal_Width': 0.3},
#  {'Sepal_Length': 5.0,
#   'Sepal_Width': 3.4,
#   'Petal_Length': 1.5,
#   'Petal_Width': 0.2},
#  {'Sepal_Length': 4.4,
#   'Sepal_Width': 2.9,
#   'Petal_Length': 1.4,
#   'Petal_Width': 0.2},
#  {'Sepal_Length': 4.9,
#   'Sepal_Width': 3.1,
#   'Petal_Length': 1.5,
#   'Petal_Width': 0.1},
# ...

# %%
with open('data/iris.json', 'w') as outfile:
    json.dump(new_iris, outfile)

# %%
with open('data/iris.json') as f:
    iris_df = json.load(f)

# %%
iris_df1 = pd.DataFrame(iris_df)

# %%
iris_df1
# Out:
#      Petal_Length  Petal_Width  Sepal_Length  Sepal_Width
# 0             1.4          0.2           5.1          3.5
# 1             1.4          0.2           4.9          3.0
# 2             1.3          0.2           4.7          3.2
# 3             1.5          0.2           4.6          3.1
# 4             1.4          0.2           5.0          3.6
# 5             1.7          0.4           5.4          3.9
# 6             1.4          0.3           4.6          3.4
# 7             1.5          0.2           5.0          3.4
# 8             1.4          0.2           4.4          2.9
# 9             1.5          0.1           4.9          3.1
# 10            1.5          0.2           5.4          3.7
# 11            1.6          0.2           4.8          3.4
# 12            1.4          0.1           4.8          3.0
# 13            1.1          0.1           4.3          3.0
# 14            1.2          0.2           5.8          4.0
# ...
